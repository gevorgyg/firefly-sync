# %%
from lib.fireflies import create_d_regular_network, Firefly
# %matplotlib notebook
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import random

n = 10
d = 3
seed = 42

# create an array with uniformly distributed values between 0 and 1
phases = np.random.uniform(0, 1, 10)

network = create_d_regular_network(phases, d, seed=seed)
pos = nx.circular_layout(network)

# %%
nx.draw(network, pos=pos)
# Out:
# <div id='4bf51fc5-582f-4e12-afe5-873973ce7052'></div>

# %%
G = nx.dodecahedral_graph()
pos = nx.spectral_layout(G, dim=3)
nodes = np.array([pos[v] for v in G])
edges = np.array([(pos[u], pos[v]) for u, v in G.edges()])

# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import numpy as np
matplotlib.use('TkAgg')
# Set up the graph
G = nx.erdos_renyi_graph(20, 0.15)  # Random graph with 20 nodes
pos = nx.spring_layout(G)  # Positions for all nodes

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 8))
plt.title('Network Graph with Changing Node Colors')

# Initial node colors (all blue to start)
node_colors = ['blue'] * len(G)

# Draw the initial graph
nodes = nx.draw_networkx_nodes(G, pos, node_color=node_colors, ax=ax)
edges = nx.draw_networkx_edges(G, pos, ax=ax)
labels = nx.draw_networkx_labels(G, pos, ax=ax)

def update(frame):
    global node_colors

    # Every 5 frames, update the colors
    if frame % 2 == 0:
        node_colors = [random.choice(['red', 'blue']) for _ in range(len(G))]

    # Update node colors
    nodes.set_array(np.array([1 if color == 'red' else 0 for color in node_colors]))
    nodes.set_cmap(plt.cm.bwr)  # Blue to red colormap

    # Optional: Update title with frame count
    ax.set_title(f'Network Graph - Frame {frame}')

    return nodes, edges, labels

# Create animation
ani = FuncAnimation(
    fig,
    update,
    frames=100,  # 100 frames total
    interval=200,  # 200ms between frames
    blit=False
)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 7
#       5 import random
#       6 import numpy as np
# ----> 7 matplotlib.use('TkAgg')
#       8 # Set up the graph
#       9 G = nx.erdos_renyi_graph(20, 0.15)  # Random graph with 20 nodes
#
# File ~/PetProjects/fireflies/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:1281, in use(backend, force)
#    1276 if plt is not None:
#    1277     try:
#    1278         # we need this import check here to re-raise if the
#    1279         # user does not have the libraries to support their
#    1280         # chosen backend installed.
# -> 1281         plt.switch_backend(name)
#    1282     except ImportError:
#    1283         if force:
#
# File ~/PetProjects/fireflies/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:425, in switch_backend(newbackend)
#     422         return
# ...
