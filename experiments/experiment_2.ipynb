# %%
from lib.experiment import Experiment
from lib.fireflies import create_d_regular_network, Firefly
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import random

n = 100
duration = 1000.0
time_step = 0.05
d = 6
seed = 42

# create an array with uniformly distributed values between 0 and 1
phases = np.random.uniform(0, 1, n)

network = create_d_regular_network(phases, d, seed=seed)
experiment = Experiment(network, duration=duration, time_step=0.1)

# %%
experiment.run()

# %%
phases = np.array(list(experiment.time_to_phase.values()))

# %%
b = np.std(phases, axis=1)

# %%
plt.plot(b)
